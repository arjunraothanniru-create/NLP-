# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
paragraph = """"
The 2003 science fiction film Koi... Mil Gaya, for which Roshan won two Filmfare
Awards, was a turning point in his film career; he later starred as the titular superhero
in its sequels: Krrish (2006) and Krrish 3 (2013). He earned praise for his portrayal of
an army officer in Lakshya (2004), a thief in Dhoom 2 (2006), Mughal emperor Akbar
in Jodhaa Akbar (2008) and a quadriplegic in Guzaarish (2010). He achieved further
commercial success with the comedy-drama Zindagi Na Milegi Dobara (2011), the revenge drama Agneepath (2012),
 the biopic Super 30 (2019), and action films directed by Siddharth Anand—Bang Bang! (2014),
  War (2019), and Fighter (2024).Roshan has also performed on stage and debuted
  on television with the dance reality show Just Dance (2011). As a judge on the latter,
   he became the highest-paid film star on Indian television at that time. He is involved with a number
    of humanitarian causes, endorses several brands and products and has launched his own clothing line. Roshan was
     married for fourteen years to Sussanne Khan, with whom he has two children.
"""

# %%
paragraph
# Out:
# '"\nThe 2003 science fiction film Koi... Mil Gaya, for which Roshan won two Filmfare\nAwards, was a turning point in his film career; he later starred as the titular superhero\nin its sequels: Krrish (2006) and Krrish 3 (2013). He earned praise for his portrayal of\nan army officer in Lakshya (2004), a thief in Dhoom 2 (2006), Mughal emperor Akbar\nin Jodhaa Akbar (2008) and a quadriplegic in Guzaarish (2010). He achieved further\ncommercial success with the comedy-drama Zindagi Na Milegi Dobara (2011), the revenge drama Agneepath (2012),\n the biopic Super 30 (2019), and action films directed by Siddharth Anand—Bang Bang! (2014),\n  War (2019), and Fighter (2024).Roshan has also performed on stage and debuted\n  on television with the dance reality show Just Dance (2011). As a judge on the latter,\n   he became the highest-paid film star on Indian television at that time. He is involved with a number\n    of humanitarian causes, endorses several brands and products and has launched 
# ...

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# %%
# tokenization = converts paragraph to sentances to words
sentences = nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ['"\nThe 2003 science fiction film Koi... Mil Gaya, for which Roshan won two Filmfare\nAwards, was a turning point in his film career; he later starred as the titular superhero\nin its sequels: Krrish (2006) and Krrish 3 (2013).',
#  'He earned praise for his portrayal of\nan army officer in Lakshya (2004), a thief in Dhoom 2 (2006), Mughal emperor Akbar\nin Jodhaa Akbar (2008) and a quadriplegic in Guzaarish (2010).',
#  'He achieved further\ncommercial success with the comedy-drama Zindagi Na Milegi Dobara (2011), the revenge drama Agneepath (2012),\n the biopic Super 30 (2019), and action films directed by Siddharth Anand—Bang Bang!',
#  '(2014),\n  War (2019), and Fighter (2024).Roshan has also performed on stage and debuted\n  on television with the dance reality show Just Dance (2011).',
#  'As a judge on the latter,\n   he became the highest-paid film star on Indian television at that time.',
# ...

# %%
type(sentences)
# Out:
# list

# %%
stemmer = PorterStemmer()

# %%
stemmer.stem('playing')
# Out:
# 'play'

# %%
stemmer.stem('historical')
# Out:
# 'histor'

# %%
stemmer.stem('history')
# Out:
# 'histori'

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize('history')
# Out:
# 'history'

# %%
len(sentences)
# Out:
# 7

# %%
import re

# %%
Corpus = []
for i in range(len(sentences)):
  review = re.sub('[^a-zA-z]','',sentences[i])
  review = review.lower()
  Corpus.append(review)

# %%
Corpus
# Out:
# ['thesciencefictionfilmkoimilgayaforwhichroshanwontwofilmfareawardswasaturningpointinhisfilmcareerhelaterstarredasthetitularsuperheroinitssequelskrrishandkrrish',
#  'heearnedpraiseforhisportrayalofanarmyofficerinlakshyaathiefindhoommughalemperorakbarinjodhaaakbarandaquadriplegicinguzaarish',
#  'heachievedfurthercommercialsuccesswiththecomedydramazindaginamilegidobaratherevengedramaagneepaththebiopicsuperandactionfilmsdirectedbysiddharthanandbangbang',
#  'warandfighterroshanhasalsoperformedonstageanddebutedontelevisionwiththedancerealityshowjustdance',
#  'asajudgeonthelatterhebecamethehighestpaidfilmstaronindiantelevisionatthattime',
#  'heisinvolvedwithanumberofhumanitariancausesendorsesseveralbrandsandproductsandhaslaunchedhisownclothingline',
#  'roshanwasmarriedforfourteenyearstosussannekhanwithwhomhehastwochildren']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#stemmer
for i in Corpus :
   words = nltk.word_tokenize(i)
   for word in words :
    if word not in set(stopwords.words('english')):
      print(stemmer.stem(word))
# Out:
# thesciencefictionfilmkoimilgayaforwhichroshanwontwofilmfareawardswasaturningpointinhisfilmcareerhelaterstarredasthetitularsuperheroinitssequelskrrishandkrrish
# heearnedpraiseforhisportrayalofanarmyofficerinlakshyaathiefindhoommughalemperorakbarinjodhaaakbarandaquadriplegicinguzaarish
# heachievedfurthercommercialsuccesswiththecomedydramazindaginamilegidobaratherevengedramaagneepaththebiopicsuperandactionfilmsdirectedbysiddharthanandbangbang
# warandfighterroshanhasalsoperformedonstageanddebutedontelevisionwiththedancerealityshowjustd
# asajudgeonthelatterhebecamethehighestpaidfilmstaronindiantelevisionatthattim
# heisinvolvedwithanumberofhumanitariancausesendorsesseveralbrandsandproductsandhaslaunchedhisownclothinglin
# roshanwasmarriedforfourteenyearstosussannekhanwithwhomhehastwochildren

# %%
#lemmatizer
